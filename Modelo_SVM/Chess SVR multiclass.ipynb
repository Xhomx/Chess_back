# %% [markdown]
# # funciona mk

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import numpy as np
import chess.pgn as chessy
import matplotlib.pyplot as plt
import tensorflow as tf
import math

session = tf.Session()

# %%
pgn = open("../../../Garry Kasparov - 2508 games.pgn")

X = []
Y = []

for i in range(1254):
    
    game = chessy.skip_game(pgn)
    game = chessy.read_game(pgn)
#     print(game)
    head = game.headers["Black"]
    resul = game.headers["Result"]
    
    if(head == 'Kasparov, Garry' and resul == '0-1'):
        board = game.board()
    
        for move in game.mainline_moves():
            Y.append(str(move))
            X.append(str(board.fen()).split(" "))
            board.push(move)
            
pgn = open("../../../Garry Kasparov - 2508 games.pgn")

for i in range(1255):
    
    game_2 = chessy.read_game(pgn)
#     print(game_2)
    head = game_2.headers["Black"]
    resul = game.headers["Result"]
    
    if(head == 'Kasparov, Garry' and resul == '0-1'):
        board_2 = game_2.board()
    
        for move in game_2.mainline_moves():
            Y.append(str(move))
            X.append(str(board_2.fen()).split(" "))
            board_2.push(move)
        
    game_2 = chessy.skip_game(pgn)

# %%
Xtis = np.array(X)
Xt = Xtis[:,0]
Xtrain = Xt[1::2]
ytrain = Y[1::2]

# %%
print(len(ytrain))
print(len(Xtrain))
Xtrain = np.array(Xtrain)
print(Xtrain)

# %%
def convertir_a_numeros(cadena):
    cadena = cadena.replace("8", "99.99.99.99.99.99.99.99.")
    cadena = cadena.replace("7", "99.99.99.99.99.99.99.")
    cadena = cadena.replace("6", "99.99.99.99.99.99.")
    cadena = cadena.replace("5", "99.99.99.99.99.")
    cadena = cadena.replace("4", "99.99.99.99.")
    cadena = cadena.replace("3", "99.99.99.")
    cadena = cadena.replace("2", "99.99.")
    cadena = cadena.replace("1", "99.")

    cadena = cadena.replace('r', '10.')
    cadena = cadena.replace('n', '11.')
    cadena = cadena.replace('b', '12.')
    cadena = cadena.replace('q', '13.')
    cadena = cadena.replace('k', '14.')
    cadena = cadena.replace('p', '15.')

    cadena = cadena.replace('R', '16.')
    cadena = cadena.replace('N', '17.')
    cadena = cadena.replace('B', '18.')
    cadena = cadena.replace('Q', '19.')
    cadena = cadena.replace('K', '20.')
    cadena = cadena.replace('P', '21.')
    
    return cadena

# %%
Xtrain_v = []

for i in range(len(Xtrain)):
    
    x = Xtrain[i].split("/")
    cadena1 = convertir_a_numeros(x[0])
    cadena2 = convertir_a_numeros(x[1])
    cadena3 = convertir_a_numeros(x[2])
    cadena4 = convertir_a_numeros(x[3])
    cadena5 = convertir_a_numeros(x[4])
    cadena6 = convertir_a_numeros(x[5])
    cadena7 = convertir_a_numeros(x[6])
    cadena8 = convertir_a_numeros(x[7])
    
    cadena_unida = cadena1 + cadena2 + cadena3 + cadena4 + cadena5 + cadena6 + cadena7 + cadena8
    Xtrain_v.append(cadena_unida)
# print(Xtrain_v)

# %%
matriz = []
for i in range(len(Xtrain_v)):
    vector = Xtrain_v[i].split(".")
    vector.pop()
    matriz.append(vector)
    
matriz = np.array(matriz)
# print(matriz)

# %%
print(matriz.shape)

# %%
matriz = matriz.astype(np.float)
# matriz

# %%
for i in range(len(ytrain)):
    ytrain[i] = ytrain[i].replace("a", "1")
    ytrain[i] = ytrain[i].replace("b", "2")
    ytrain[i] = ytrain[i].replace("c", "3")
    ytrain[i] = ytrain[i].replace("d", "4")
    ytrain[i] = ytrain[i].replace("e", "5")
    ytrain[i] = ytrain[i].replace("f", "6")
    ytrain[i] = ytrain[i].replace("g", "7")
    ytrain[i] = ytrain[i].replace("h", "8")
    ytrain[i] = ytrain[i].replace("q", "")
    
# print(ytrain)

# %%
ytrain = np.array(ytrain)
ytrain = ytrain.astype(np.float)
# print(ytrain)

# %%
targetss = []
for i in range(1112,8888):
    s = math.floor(i/100)
    se = math.floor(i % 100)
    if(s != se):
        if(s % 10 != 0):
            if(s % 10 != 9):
                if(i % 10 != 0):
                    sec = i/10
                    if(math.floor(sec % 10) != 0):
                        if(i % 10 != 9):
                            sec_2 = i/10
                            if(math.floor(sec % 10) != 9):
                                targetss.append(i)
                            
for i in targetss:
    exec('y_train{} = np.array([1 if y == i else -1 for y in ytrain])'.format(i))
    
y_vals = np.array([y_train1112, y_train1113, y_train1114, y_train1115, y_train1116, y_train1117, y_train1118, y_train1121, y_train1122, y_train1123, y_train1124, y_train1125, y_train1126, y_train1127, y_train1128, y_train1131, y_train1132, y_train1133, y_train1134, y_train1135, y_train1136, y_train1137, y_train1138, y_train1141, y_train1142, y_train1143, y_train1144, y_train1145, y_train1146, y_train1147, y_train1148, y_train1151, y_train1152, y_train1153, y_train1154, y_train1155, y_train1156, y_train1157, y_train1158, y_train1161, y_train1162, y_train1163, y_train1164, y_train1165, y_train1166, y_train1167, y_train1168, y_train1171, y_train1172, y_train1173, y_train1174, y_train1175, y_train1176, y_train1177, y_train1178, y_train1181, y_train1182, y_train1183, y_train1184, y_train1185, y_train1186, y_train1187, y_train1188, y_train1211, y_train1213, y_train1214, y_train1215, y_train1216, y_train1217, y_train1218, y_train1221, y_train1222, y_train1223, y_train1224, y_train1225, y_train1226, y_train1227, y_train1228, y_train1231, y_train1232, y_train1233, y_train1234, y_train1235, y_train1236, y_train1237, y_train1238, y_train1241, y_train1242, y_train1243, y_train1244, y_train1245, y_train1246, y_train1247, y_train1248, y_train1251, y_train1252, y_train1253, y_train1254, y_train1255, y_train1256, y_train1257, y_train1258, y_train1261, y_train1262, y_train1263, y_train1264, y_train1265, y_train1266, y_train1267, y_train1268, y_train1271, y_train1272, y_train1273, y_train1274, y_train1275, y_train1276, y_train1277, y_train1278, y_train1281, y_train1282, y_train1283, y_train1284, y_train1285, y_train1286, y_train1287, y_train1288, y_train1311, y_train1312, y_train1314, y_train1315, y_train1316, y_train1317, y_train1318, y_train1321, y_train1322, y_train1323, y_train1324, y_train1325, y_train1326, y_train1327, y_train1328, y_train1331, y_train1332, y_train1333, y_train1334, y_train1335, y_train1336, y_train1337, y_train1338, y_train1341, y_train1342, y_train1343, y_train1344, y_train1345, y_train1346, y_train1347, y_train1348, y_train1351, y_train1352, y_train1353, y_train1354, y_train1355, y_train1356, y_train1357, y_train1358, y_train1361, y_train1362, y_train1363, y_train1364, y_train1365, y_train1366, y_train1367, y_train1368, y_train1371, y_train1372, y_train1373, y_train1374, y_train1375, y_train1376, y_train1377, y_train1378, y_train1381, y_train1382, y_train1383, y_train1384, y_train1385, y_train1386, y_train1387, y_train1388, y_train1411, y_train1412, y_train1413, y_train1415, y_train1416, y_train1417, y_train1418, y_train1421, y_train1422, y_train1423, y_train1424, y_train1425, y_train1426, y_train1427, y_train1428, y_train1431, y_train1432, y_train1433, y_train1434, y_train1435, y_train1436, y_train1437, y_train1438, y_train1441, y_train1442, y_train1443, y_train1444, y_train1445, y_train1446, y_train1447, y_train1448, y_train1451, y_train1452, y_train1453, y_train1454, y_train1455, y_train1456, y_train1457, y_train1458, y_train1461, y_train1462, y_train1463, y_train1464, y_train1465, y_train1466, y_train1467, y_train1468, y_train1471, y_train1472, y_train1473, y_train1474, y_train1475, y_train1476, y_train1477, y_train1478, y_train1481, y_train1482, y_train1483, y_train1484, y_train1485, y_train1486, y_train1487, y_train1488, y_train1511, y_train1512, y_train1513, y_train1514, y_train1516, y_train1517, y_train1518, y_train1521, y_train1522, y_train1523, y_train1524, y_train1525, y_train1526, y_train1527, y_train1528, y_train1531, y_train1532, y_train1533, y_train1534, y_train1535, y_train1536, y_train1537, y_train1538, y_train1541, y_train1542, y_train1543, y_train1544, y_train1545, y_train1546, y_train1547, y_train1548, y_train1551, y_train1552, y_train1553, y_train1554, y_train1555, y_train1556, y_train1557, y_train1558, y_train1561, y_train1562, y_train1563, y_train1564, y_train1565, y_train1566, y_train1567, y_train1568, y_train1571, y_train1572, y_train1573, y_train1574, y_train1575, y_train1576, y_train1577, y_train1578, y_train1581, y_train1582, y_train1583, y_train1584, y_train1585, y_train1586, y_train1587, y_train1588, y_train1611, y_train1612, y_train1613, y_train1614, y_train1615, y_train1617, y_train1618, y_train1621, y_train1622, y_train1623, y_train1624, y_train1625, y_train1626, y_train1627, y_train1628, y_train1631, y_train1632, y_train1633, y_train1634, y_train1635, y_train1636, y_train1637, y_train1638, y_train1641, y_train1642, y_train1643, y_train1644, y_train1645, y_train1646, y_train1647, y_train1648, y_train1651, y_train1652, y_train1653, y_train1654, y_train1655, y_train1656, y_train1657, y_train1658, y_train1661, y_train1662, y_train1663, y_train1664, y_train1665, y_train1666, y_train1667, y_train1668, y_train1671, y_train1672, y_train1673, y_train1674, y_train1675, y_train1676, y_train1677, y_train1678, y_train1681, y_train1682, y_train1683, y_train1684, y_train1685, y_train1686, y_train1687, y_train1688, y_train1711, y_train1712, y_train1713, y_train1714, y_train1715, y_train1716, y_train1718, y_train1721, y_train1722, y_train1723, y_train1724, y_train1725, y_train1726, y_train1727, y_train1728, y_train1731, y_train1732, y_train1733, y_train1734, y_train1735, y_train1736, y_train1737, y_train1738, y_train1741, y_train1742, y_train1743, y_train1744, y_train1745, y_train1746, y_train1747, y_train1748, y_train1751, y_train1752, y_train1753, y_train1754, y_train1755, y_train1756, y_train1757, y_train1758, y_train1761, y_train1762, y_train1763, y_train1764, y_train1765, y_train1766, y_train1767, y_train1768, y_train1771, y_train1772, y_train1773, y_train1774, y_train1775, y_train1776, y_train1777, y_train1778, y_train1781, y_train1782, y_train1783, y_train1784, y_train1785, y_train1786, y_train1787, y_train1788, y_train1811, y_train1812, y_train1813, y_train1814, y_train1815, y_train1816, y_train1817, y_train1821, y_train1822, y_train1823, y_train1824, y_train1825, y_train1826, y_train1827, y_train1828, y_train1831, y_train1832, y_train1833, y_train1834, y_train1835, y_train1836, y_train1837, y_train1838, y_train1841, y_train1842, y_train1843, y_train1844, y_train1845, y_train1846, y_train1847, y_train1848, y_train1851, y_train1852, y_train1853, y_train1854, y_train1855, y_train1856, y_train1857, y_train1858, y_train1861, y_train1862, y_train1863, y_train1864, y_train1865, y_train1866, y_train1867, y_train1868, y_train1871, y_train1872, y_train1873, y_train1874, y_train1875, y_train1876, y_train1877, y_train1878, y_train1881, y_train1882, y_train1883, y_train1884, y_train1885, y_train1886, y_train1887, y_train1888, y_train2111, y_train2112, y_train2113, y_train2114, y_train2115, y_train2116, y_train2117, y_train2118, y_train2122, y_train2123, y_train2124, y_train2125, y_train2126, y_train2127, y_train2128, y_train2131, y_train2132, y_train2133, y_train2134, y_train2135, y_train2136, y_train2137, y_train2138, y_train2141, y_train2142, y_train2143, y_train2144, y_train2145, y_train2146, y_train2147, y_train2148, y_train2151, y_train2152, y_train2153, y_train2154, y_train2155, y_train2156, y_train2157, y_train2158, y_train2161, y_train2162, y_train2163, y_train2164, y_train2165, y_train2166, y_train2167, y_train2168, y_train2171, y_train2172, y_train2173, y_train2174, y_train2175, y_train2176, y_train2177, y_train2178, y_train2181, y_train2182, y_train2183, y_train2184, y_train2185, y_train2186, y_train2187, y_train2188, y_train2211, y_train2212, y_train2213, y_train2214, y_train2215, y_train2216, y_train2217, y_train2218, y_train2221, y_train2223, y_train2224, y_train2225, y_train2226, y_train2227, y_train2228, y_train2231, y_train2232, y_train2233, y_train2234, y_train2235, y_train2236, y_train2237, y_train2238, y_train2241, y_train2242, y_train2243, y_train2244, y_train2245, y_train2246, y_train2247, y_train2248, y_train2251, y_train2252, y_train2253, y_train2254, y_train2255, y_train2256, y_train2257, y_train2258, y_train2261, y_train2262, y_train2263, y_train2264, y_train2265, y_train2266, y_train2267, y_train2268, y_train2271, y_train2272, y_train2273, y_train2274, y_train2275, y_train2276, y_train2277, y_train2278, y_train2281, y_train2282, y_train2283, y_train2284, y_train2285, y_train2286, y_train2287, y_train2288, y_train2311, y_train2312, y_train2313, y_train2314, y_train2315, y_train2316, y_train2317, y_train2318, y_train2321, y_train2322, y_train2324, y_train2325, y_train2326, y_train2327, y_train2328, y_train2331, y_train2332, y_train2333, y_train2334, y_train2335, y_train2336, y_train2337, y_train2338, y_train2341, y_train2342, y_train2343, y_train2344, y_train2345, y_train2346, y_train2347, y_train2348, y_train2351, y_train2352, y_train2353, y_train2354, y_train2355, y_train2356, y_train2357, y_train2358, y_train2361, y_train2362, y_train2363, y_train2364, y_train2365, y_train2366, y_train2367, y_train2368, y_train2371, y_train2372, y_train2373, y_train2374, y_train2375, y_train2376, y_train2377, y_train2378, y_train2381, y_train2382, y_train2383, y_train2384, y_train2385, y_train2386, y_train2387, y_train2388, y_train2411, y_train2412, y_train2413, y_train2414, y_train2415, y_train2416, y_train2417, y_train2418, y_train2421, y_train2422, y_train2423, y_train2425, y_train2426, y_train2427, y_train2428, y_train2431, y_train2432, y_train2433, y_train2434, y_train2435, y_train2436, y_train2437, y_train2438, y_train2441, y_train2442, y_train2443, y_train2444, y_train2445, y_train2446, y_train2447, y_train2448, y_train2451, y_train2452, y_train2453, y_train2454, y_train2455, y_train2456, y_train2457, y_train2458, y_train2461, y_train2462, y_train2463, y_train2464, y_train2465, y_train2466, y_train2467, y_train2468, y_train2471, y_train2472, y_train2473, y_train2474, y_train2475, y_train2476, y_train2477, y_train2478, y_train2481, y_train2482, y_train2483, y_train2484, y_train2485, y_train2486, y_train2487, y_train2488, y_train2511, y_train2512, y_train2513, y_train2514, y_train2515, y_train2516, y_train2517, y_train2518, y_train2521, y_train2522, y_train2523, y_train2524, y_train2526, y_train2527, y_train2528, y_train2531, y_train2532, y_train2533, y_train2534, y_train2535, y_train2536, y_train2537, y_train2538, y_train2541, y_train2542, y_train2543, y_train2544, y_train2545, y_train2546, y_train2547, y_train2548, y_train2551, y_train2552, y_train2553, y_train2554, y_train2555, y_train2556, y_train2557, y_train2558, y_train2561, y_train2562, y_train2563, y_train2564, y_train2565, y_train2566, y_train2567, y_train2568, y_train2571, y_train2572, y_train2573, y_train2574, y_train2575, y_train2576, y_train2577, y_train2578, y_train2581, y_train2582, y_train2583, y_train2584, y_train2585, y_train2586, y_train2587, y_train2588, y_train2611, y_train2612, y_train2613, y_train2614, y_train2615, y_train2616, y_train2617, y_train2618, y_train2621, y_train2622, y_train2623, y_train2624, y_train2625, y_train2627, y_train2628, y_train2631, y_train2632, y_train2633, y_train2634, y_train2635, y_train2636, y_train2637, y_train2638, y_train2641, y_train2642, y_train2643, y_train2644, y_train2645, y_train2646, y_train2647, y_train2648, y_train2651, y_train2652, y_train2653, y_train2654, y_train2655, y_train2656, y_train2657, y_train2658, y_train2661, y_train2662, y_train2663, y_train2664, y_train2665, y_train2666, y_train2667, y_train2668, y_train2671, y_train2672, y_train2673, y_train2674, y_train2675, y_train2676, y_train2677, y_train2678, y_train2681, y_train2682, y_train2683, y_train2684, y_train2685, y_train2686, y_train2687, y_train2688, y_train2711, y_train2712, y_train2713, y_train2714, y_train2715, y_train2716, y_train2717, y_train2718, y_train2721, y_train2722, y_train2723, y_train2724, y_train2725, y_train2726, y_train2728, y_train2731, y_train2732, y_train2733, y_train2734, y_train2735, y_train2736, y_train2737, y_train2738, y_train2741, y_train2742, y_train2743, y_train2744, y_train2745, y_train2746, y_train2747, y_train2748, y_train2751, y_train2752, y_train2753, y_train2754, y_train2755, y_train2756, y_train2757, y_train2758, y_train2761, y_train2762, y_train2763, y_train2764, y_train2765, y_train2766, y_train2767, y_train2768, y_train2771, y_train2772, y_train2773, y_train2774, y_train2775, y_train2776, y_train2777, y_train2778, y_train2781, y_train2782, y_train2783, y_train2784, y_train2785, y_train2786, y_train2787, y_train2788, y_train2811, y_train2812, y_train2813, y_train2814, y_train2815, y_train2816, y_train2817, y_train2818, y_train2821, y_train2822, y_train2823, y_train2824, y_train2825, y_train2826, y_train2827, y_train2831, y_train2832, y_train2833, y_train2834, y_train2835, y_train2836, y_train2837, y_train2838, y_train2841, y_train2842, y_train2843, y_train2844, y_train2845, y_train2846, y_train2847, y_train2848, y_train2851, y_train2852, y_train2853, y_train2854, y_train2855, y_train2856, y_train2857, y_train2858, y_train2861, y_train2862, y_train2863, y_train2864, y_train2865, y_train2866, y_train2867, y_train2868, y_train2871, y_train2872, y_train2873, y_train2874, y_train2875, y_train2876, y_train2877, y_train2878, y_train2881, y_train2882, y_train2883, y_train2884, y_train2885, y_train2886, y_train2887, y_train2888, y_train3111, y_train3112, y_train3113, y_train3114, y_train3115, y_train3116, y_train3117, y_train3118, y_train3121, y_train3122, y_train3123, y_train3124, y_train3125, y_train3126, y_train3127, y_train3128, y_train3132, y_train3133, y_train3134, y_train3135, y_train3136, y_train3137, y_train3138, y_train3141, y_train3142, y_train3143, y_train3144, y_train3145, y_train3146, y_train3147, y_train3148, y_train3151, y_train3152, y_train3153, y_train3154, y_train3155, y_train3156, y_train3157, y_train3158, y_train3161, y_train3162, y_train3163, y_train3164, y_train3165, y_train3166, y_train3167, y_train3168, y_train3171, y_train3172, y_train3173, y_train3174, y_train3175, y_train3176, y_train3177, y_train3178, y_train3181, y_train3182, y_train3183, y_train3184, y_train3185, y_train3186, y_train3187, y_train3188, y_train3211, y_train3212, y_train3213, y_train3214, y_train3215, y_train3216, y_train3217, y_train3218, y_train3221, y_train3222, y_train3223, y_train3224, y_train3225, y_train3226, y_train3227, y_train3228, y_train3231, y_train3233, y_train3234, y_train3235, y_train3236, y_train3237, y_train3238, y_train3241, y_train3242, y_train3243, y_train3244, y_train3245, y_train3246, y_train3247, y_train3248, y_train3251, y_train3252, y_train3253, y_train3254, y_train3255, y_train3256, y_train3257, y_train3258, y_train3261, y_train3262, y_train3263, y_train3264, y_train3265, y_train3266, y_train3267, y_train3268, y_train3271, y_train3272, y_train3273, y_train3274, y_train3275, y_train3276, y_train3277, y_train3278, y_train3281, y_train3282, y_train3283, y_train3284, y_train3285, y_train3286, y_train3287, y_train3288, y_train3311, y_train3312, y_train3313, y_train3314, y_train3315, y_train3316, y_train3317, y_train3318, y_train3321, y_train3322, y_train3323, y_train3324, y_train3325, y_train3326, y_train3327, y_train3328, y_train3331, y_train3332, y_train3334, y_train3335, y_train3336, y_train3337, y_train3338, y_train3341, y_train3342, y_train3343, y_train3344, y_train3345, y_train3346, y_train3347, y_train3348, y_train3351, y_train3352, y_train3353, y_train3354, y_train3355, y_train3356, y_train3357, y_train3358, y_train3361, y_train3362, y_train3363, y_train3364, y_train3365, y_train3366, y_train3367, y_train3368, y_train3371, y_train3372, y_train3373, y_train3374, y_train3375, y_train3376, y_train3377, y_train3378, y_train3381, y_train3382, y_train3383, y_train3384, y_train3385, y_train3386, y_train3387, y_train3388, y_train3411, y_train3412, y_train3413, y_train3414, y_train3415, y_train3416, y_train3417, y_train3418, y_train3421, y_train3422, y_train3423, y_train3424, y_train3425, y_train3426, y_train3427, y_train3428, y_train3431, y_train3432, y_train3433, y_train3435, y_train3436, y_train3437, y_train3438, y_train3441, y_train3442, y_train3443, y_train3444, y_train3445, y_train3446, y_train3447, y_train3448, y_train3451, y_train3452, y_train3453, y_train3454, y_train3455, y_train3456, y_train3457, y_train3458, y_train3461, y_train3462, y_train3463, y_train3464, y_train3465, y_train3466, y_train3467, y_train3468, y_train3471, y_train3472, y_train3473, y_train3474, y_train3475, y_train3476, y_train3477, y_train3478, y_train3481, y_train3482, y_train3483, y_train3484, y_train3485, y_train3486, y_train3487, y_train3488, y_train3511, y_train3512, y_train3513, y_train3514, y_train3515, y_train3516, y_train3517, y_train3518, y_train3521, y_train3522, y_train3523, y_train3524, y_train3525, y_train3526, y_train3527, y_train3528, y_train3531, y_train3532, y_train3533, y_train3534, y_train3536, y_train3537, y_train3538, y_train3541, y_train3542, y_train3543, y_train3544, y_train3545, y_train3546, y_train3547, y_train3548, y_train3551, y_train3552, y_train3553, y_train3554, y_train3555, y_train3556, y_train3557, y_train3558, y_train3561, y_train3562, y_train3563, y_train3564, y_train3565, y_train3566, y_train3567, y_train3568, y_train3571, y_train3572, y_train3573, y_train3574, y_train3575, y_train3576, y_train3577, y_train3578, y_train3581, y_train3582, y_train3583, y_train3584, y_train3585, y_train3586, y_train3587, y_train3588, y_train3611, y_train3612, y_train3613, y_train3614, y_train3615, y_train3616, y_train3617, y_train3618, y_train3621, y_train3622, y_train3623, y_train3624, y_train3625, y_train3626, y_train3627, y_train3628, y_train3631, y_train3632, y_train3633, y_train3634, y_train3635, y_train3637, y_train3638, y_train3641, y_train3642, y_train3643, y_train3644, y_train3645, y_train3646, y_train3647, y_train3648, y_train3651, y_train3652, y_train3653, y_train3654, y_train3655, y_train3656, y_train3657, y_train3658, y_train3661, y_train3662, y_train3663, y_train3664, y_train3665, y_train3666, y_train3667, y_train3668, y_train3671, y_train3672, y_train3673, y_train3674, y_train3675, y_train3676, y_train3677, y_train3678, y_train3681, y_train3682, y_train3683, y_train3684, y_train3685, y_train3686, y_train3687, y_train3688, y_train3711, y_train3712, y_train3713, y_train3714, y_train3715, y_train3716, y_train3717, y_train3718, y_train3721, y_train3722, y_train3723, y_train3724, y_train3725, y_train3726, y_train3727, y_train3728, y_train3731, y_train3732, y_train3733, y_train3734, y_train3735, y_train3736, y_train3738, y_train3741, y_train3742, y_train3743, y_train3744, y_train3745, y_train3746, y_train3747, y_train3748, y_train3751, y_train3752, y_train3753, y_train3754, y_train3755, y_train3756, y_train3757, y_train3758, y_train3761, y_train3762, y_train3763, y_train3764, y_train3765, y_train3766, y_train3767, y_train3768, y_train3771, y_train3772, y_train3773, y_train3774, y_train3775, y_train3776, y_train3777, y_train3778, y_train3781, y_train3782, y_train3783, y_train3784, y_train3785, y_train3786, y_train3787, y_train3788, y_train3811, y_train3812, y_train3813, y_train3814, y_train3815, y_train3816, y_train3817, y_train3818, y_train3821, y_train3822, y_train3823, y_train3824, y_train3825, y_train3826, y_train3827, y_train3828, y_train3831, y_train3832, y_train3833, y_train3834, y_train3835, y_train3836, y_train3837, y_train3841, y_train3842, y_train3843, y_train3844, y_train3845, y_train3846, y_train3847, y_train3848, y_train3851, y_train3852, y_train3853, y_train3854, y_train3855, y_train3856, y_train3857, y_train3858, y_train3861, y_train3862, y_train3863, y_train3864, y_train3865, y_train3866, y_train3867, y_train3868, y_train3871, y_train3872, y_train3873, y_train3874, y_train3875, y_train3876, y_train3877, y_train3878, y_train3881, y_train3882, y_train3883, y_train3884, y_train3885, y_train3886, y_train3887, y_train3888, y_train4111, y_train4112, y_train4113, y_train4114, y_train4115, y_train4116, y_train4117, y_train4118, y_train4121, y_train4122, y_train4123, y_train4124, y_train4125, y_train4126, y_train4127, y_train4128, y_train4131, y_train4132, y_train4133, y_train4134, y_train4135, y_train4136, y_train4137, y_train4138, y_train4142, y_train4143, y_train4144, y_train4145, y_train4146, y_train4147, y_train4148, y_train4151, y_train4152, y_train4153, y_train4154, y_train4155, y_train4156, y_train4157, y_train4158, y_train4161, y_train4162, y_train4163, y_train4164, y_train4165, y_train4166, y_train4167, y_train4168, y_train4171, y_train4172, y_train4173, y_train4174, y_train4175, y_train4176, y_train4177, y_train4178, y_train4181, y_train4182, y_train4183, y_train4184, y_train4185, y_train4186, y_train4187, y_train4188, y_train4211, y_train4212, y_train4213, y_train4214, y_train4215, y_train4216, y_train4217, y_train4218, y_train4221, y_train4222, y_train4223, y_train4224, y_train4225, y_train4226, y_train4227, y_train4228, y_train4231, y_train4232, y_train4233, y_train4234, y_train4235, y_train4236, y_train4237, y_train4238, y_train4241, y_train4243, y_train4244, y_train4245, y_train4246, y_train4247, y_train4248, y_train4251, y_train4252, y_train4253, y_train4254, y_train4255, y_train4256, y_train4257, y_train4258, y_train4261, y_train4262, y_train4263, y_train4264, y_train4265, y_train4266, y_train4267, y_train4268, y_train4271, y_train4272, y_train4273, y_train4274, y_train4275, y_train4276, y_train4277, y_train4278, y_train4281, y_train4282, y_train4283, y_train4284, y_train4285, y_train4286, y_train4287, y_train4288, y_train4311, y_train4312, y_train4313, y_train4314, y_train4315, y_train4316, y_train4317, y_train4318, y_train4321, y_train4322, y_train4323, y_train4324, y_train4325, y_train4326, y_train4327, y_train4328, y_train4331, y_train4332, y_train4333, y_train4334, y_train4335, y_train4336, y_train4337, y_train4338, y_train4341, y_train4342, y_train4344, y_train4345, y_train4346, y_train4347, y_train4348, y_train4351, y_train4352, y_train4353, y_train4354, y_train4355, y_train4356, y_train4357, y_train4358, y_train4361, y_train4362, y_train4363, y_train4364, y_train4365, y_train4366, y_train4367, y_train4368, y_train4371, y_train4372, y_train4373, y_train4374, y_train4375, y_train4376, y_train4377, y_train4378, y_train4381, y_train4382, y_train4383, y_train4384, y_train4385, y_train4386, y_train4387, y_train4388, y_train4411, y_train4412, y_train4413, y_train4414, y_train4415, y_train4416, y_train4417, y_train4418, y_train4421, y_train4422, y_train4423, y_train4424, y_train4425, y_train4426, y_train4427, y_train4428, y_train4431, y_train4432, y_train4433, y_train4434, y_train4435, y_train4436, y_train4437, y_train4438, y_train4441, y_train4442, y_train4443, y_train4445, y_train4446, y_train4447, y_train4448, y_train4451, y_train4452, y_train4453, y_train4454, y_train4455, y_train4456, y_train4457, y_train4458, y_train4461, y_train4462, y_train4463, y_train4464, y_train4465, y_train4466, y_train4467, y_train4468, y_train4471, y_train4472, y_train4473, y_train4474, y_train4475, y_train4476, y_train4477, y_train4478, y_train4481, y_train4482, y_train4483, y_train4484, y_train4485, y_train4486, y_train4487, y_train4488, y_train4511, y_train4512, y_train4513, y_train4514, y_train4515, y_train4516, y_train4517, y_train4518, y_train4521, y_train4522, y_train4523, y_train4524, y_train4525, y_train4526, y_train4527, y_train4528, y_train4531, y_train4532, y_train4533, y_train4534, y_train4535, y_train4536, y_train4537, y_train4538, y_train4541, y_train4542, y_train4543, y_train4544, y_train4546, y_train4547, y_train4548, y_train4551, y_train4552, y_train4553, y_train4554, y_train4555, y_train4556, y_train4557, y_train4558, y_train4561, y_train4562, y_train4563, y_train4564, y_train4565, y_train4566, y_train4567, y_train4568, y_train4571, y_train4572, y_train4573, y_train4574, y_train4575, y_train4576, y_train4577, y_train4578, y_train4581, y_train4582, y_train4583, y_train4584, y_train4585, y_train4586, y_train4587, y_train4588, y_train4611, y_train4612, y_train4613, y_train4614, y_train4615, y_train4616, y_train4617, y_train4618, y_train4621, y_train4622, y_train4623, y_train4624, y_train4625, y_train4626, y_train4627, y_train4628, y_train4631, y_train4632, y_train4633, y_train4634, y_train4635, y_train4636, y_train4637, y_train4638, y_train4641, y_train4642, y_train4643, y_train4644, y_train4645, y_train4647, y_train4648, y_train4651, y_train4652, y_train4653, y_train4654, y_train4655, y_train4656, y_train4657, y_train4658, y_train4661, y_train4662, y_train4663, y_train4664, y_train4665, y_train4666, y_train4667, y_train4668, y_train4671, y_train4672, y_train4673, y_train4674, y_train4675, y_train4676, y_train4677, y_train4678, y_train4681, y_train4682, y_train4683, y_train4684, y_train4685, y_train4686, y_train4687, y_train4688, y_train4711, y_train4712, y_train4713, y_train4714, y_train4715, y_train4716, y_train4717, y_train4718, y_train4721, y_train4722, y_train4723, y_train4724, y_train4725, y_train4726, y_train4727, y_train4728, y_train4731, y_train4732, y_train4733, y_train4734, y_train4735, y_train4736, y_train4737, y_train4738, y_train4741, y_train4742, y_train4743, y_train4744, y_train4745, y_train4746, y_train4748, y_train4751, y_train4752, y_train4753, y_train4754, y_train4755, y_train4756, y_train4757, y_train4758, y_train4761, y_train4762, y_train4763, y_train4764, y_train4765, y_train4766, y_train4767, y_train4768, y_train4771, y_train4772, y_train4773, y_train4774, y_train4775, y_train4776, y_train4777, y_train4778, y_train4781, y_train4782, y_train4783, y_train4784, y_train4785, y_train4786, y_train4787, y_train4788, y_train4811, y_train4812, y_train4813, y_train4814, y_train4815, y_train4816, y_train4817, y_train4818, y_train4821, y_train4822, y_train4823, y_train4824, y_train4825, y_train4826, y_train4827, y_train4828, y_train4831, y_train4832, y_train4833, y_train4834, y_train4835, y_train4836, y_train4837, y_train4838, y_train4841, y_train4842, y_train4843, y_train4844, y_train4845, y_train4846, y_train4847, y_train4851, y_train4852, y_train4853, y_train4854, y_train4855, y_train4856, y_train4857, y_train4858, y_train4861, y_train4862, y_train4863, y_train4864, y_train4865, y_train4866, y_train4867, y_train4868, y_train4871, y_train4872, y_train4873, y_train4874, y_train4875, y_train4876, y_train4877, y_train4878, y_train4881, y_train4882, y_train4883, y_train4884, y_train4885, y_train4886, y_train4887, y_train4888, y_train5111, y_train5112, y_train5113, y_train5114, y_train5115, y_train5116, y_train5117, y_train5118, y_train5121, y_train5122, y_train5123, y_train5124, y_train5125, y_train5126, y_train5127, y_train5128, y_train5131, y_train5132, y_train5133, y_train5134, y_train5135, y_train5136, y_train5137, y_train5138, y_train5141, y_train5142, y_train5143, y_train5144, y_train5145, y_train5146, y_train5147, y_train5148, y_train5152, y_train5153, y_train5154, y_train5155, y_train5156, y_train5157, y_train5158, y_train5161, y_train5162, y_train5163, y_train5164, y_train5165, y_train5166, y_train5167, y_train5168, y_train5171, y_train5172, y_train5173, y_train5174, y_train5175, y_train5176, y_train5177, y_train5178, y_train5181, y_train5182, y_train5183, y_train5184, y_train5185, y_train5186, y_train5187, y_train5188, y_train5211, y_train5212, y_train5213, y_train5214, y_train5215, y_train5216, y_train5217, y_train5218, y_train5221, y_train5222, y_train5223, y_train5224, y_train5225, y_train5226, y_train5227, y_train5228, y_train5231, y_train5232, y_train5233, y_train5234, y_train5235, y_train5236, y_train5237, y_train5238, y_train5241, y_train5242, y_train5243, y_train5244, y_train5245, y_train5246, y_train5247, y_train5248, y_train5251, y_train5253, y_train5254, y_train5255, y_train5256, y_train5257, y_train5258, y_train5261, y_train5262, y_train5263, y_train5264, y_train5265, y_train5266, y_train5267, y_train5268, y_train5271, y_train5272, y_train5273, y_train5274, y_train5275, y_train5276, y_train5277, y_train5278, y_train5281, y_train5282, y_train5283, y_train5284, y_train5285, y_train5286, y_train5287, y_train5288, y_train5311, y_train5312, y_train5313, y_train5314, y_train5315, y_train5316, y_train5317, y_train5318, y_train5321, y_train5322, y_train5323, y_train5324, y_train5325, y_train5326, y_train5327, y_train5328, y_train5331, y_train5332, y_train5333, y_train5334, y_train5335, y_train5336, y_train5337, y_train5338, y_train5341, y_train5342, y_train5343, y_train5344, y_train5345, y_train5346, y_train5347, y_train5348, y_train5351, y_train5352, y_train5354, y_train5355, y_train5356, y_train5357, y_train5358, y_train5361, y_train5362, y_train5363, y_train5364, y_train5365, y_train5366, y_train5367, y_train5368, y_train5371, y_train5372, y_train5373, y_train5374, y_train5375, y_train5376, y_train5377, y_train5378, y_train5381, y_train5382, y_train5383, y_train5384, y_train5385, y_train5386, y_train5387, y_train5388, y_train5411, y_train5412, y_train5413, y_train5414, y_train5415, y_train5416, y_train5417, y_train5418, y_train5421, y_train5422, y_train5423, y_train5424, y_train5425, y_train5426, y_train5427, y_train5428, y_train5431, y_train5432, y_train5433, y_train5434, y_train5435, y_train5436, y_train5437, y_train5438, y_train5441, y_train5442, y_train5443, y_train5444, y_train5445, y_train5446, y_train5447, y_train5448, y_train5451, y_train5452, y_train5453, y_train5455, y_train5456, y_train5457, y_train5458, y_train5461, y_train5462, y_train5463, y_train5464, y_train5465, y_train5466, y_train5467, y_train5468, y_train5471, y_train5472, y_train5473, y_train5474, y_train5475, y_train5476, y_train5477, y_train5478, y_train5481, y_train5482, y_train5483, y_train5484, y_train5485, y_train5486, y_train5487, y_train5488, y_train5511, y_train5512, y_train5513, y_train5514, y_train5515, y_train5516, y_train5517, y_train5518, y_train5521, y_train5522, y_train5523, y_train5524, y_train5525, y_train5526, y_train5527, y_train5528, y_train5531, y_train5532, y_train5533, y_train5534, y_train5535, y_train5536, y_train5537, y_train5538, y_train5541, y_train5542, y_train5543, y_train5544, y_train5545, y_train5546, y_train5547, y_train5548, y_train5551, y_train5552, y_train5553, y_train5554, y_train5556, y_train5557, y_train5558, y_train5561, y_train5562, y_train5563, y_train5564, y_train5565, y_train5566, y_train5567, y_train5568, y_train5571, y_train5572, y_train5573, y_train5574, y_train5575, y_train5576, y_train5577, y_train5578, y_train5581, y_train5582, y_train5583, y_train5584, y_train5585, y_train5586, y_train5587, y_train5588, y_train5611, y_train5612, y_train5613, y_train5614, y_train5615, y_train5616, y_train5617, y_train5618, y_train5621, y_train5622, y_train5623, y_train5624, y_train5625, y_train5626, y_train5627, y_train5628, y_train5631, y_train5632, y_train5633, y_train5634, y_train5635, y_train5636, y_train5637, y_train5638, y_train5641, y_train5642, y_train5643, y_train5644, y_train5645, y_train5646, y_train5647, y_train5648, y_train5651, y_train5652, y_train5653, y_train5654, y_train5655, y_train5657, y_train5658, y_train5661, y_train5662, y_train5663, y_train5664, y_train5665, y_train5666, y_train5667, y_train5668, y_train5671, y_train5672, y_train5673, y_train5674, y_train5675, y_train5676, y_train5677, y_train5678, y_train5681, y_train5682, y_train5683, y_train5684, y_train5685, y_train5686, y_train5687, y_train5688, y_train5711, y_train5712, y_train5713, y_train5714, y_train5715, y_train5716, y_train5717, y_train5718, y_train5721, y_train5722, y_train5723, y_train5724, y_train5725, y_train5726, y_train5727, y_train5728, y_train5731, y_train5732, y_train5733, y_train5734, y_train5735, y_train5736, y_train5737, y_train5738, y_train5741, y_train5742, y_train5743, y_train5744, y_train5745, y_train5746, y_train5747, y_train5748, y_train5751, y_train5752, y_train5753, y_train5754, y_train5755, y_train5756, y_train5758, y_train5761, y_train5762, y_train5763, y_train5764, y_train5765, y_train5766, y_train5767, y_train5768, y_train5771, y_train5772, y_train5773, y_train5774, y_train5775, y_train5776, y_train5777, y_train5778, y_train5781, y_train5782, y_train5783, y_train5784, y_train5785, y_train5786, y_train5787, y_train5788, y_train5811, y_train5812, y_train5813, y_train5814, y_train5815, y_train5816, y_train5817, y_train5818, y_train5821, y_train5822, y_train5823, y_train5824, y_train5825, y_train5826, y_train5827, y_train5828, y_train5831, y_train5832, y_train5833, y_train5834, y_train5835, y_train5836, y_train5837, y_train5838, y_train5841, y_train5842, y_train5843, y_train5844, y_train5845, y_train5846, y_train5847, y_train5848, y_train5851, y_train5852, y_train5853, y_train5854, y_train5855, y_train5856, y_train5857, y_train5861, y_train5862, y_train5863, y_train5864, y_train5865, y_train5866, y_train5867, y_train5868, y_train5871, y_train5872, y_train5873, y_train5874, y_train5875, y_train5876, y_train5877, y_train5878, y_train5881, y_train5882, y_train5883, y_train5884, y_train5885, y_train5886, y_train5887, y_train5888, y_train6111, y_train6112, y_train6113, y_train6114, y_train6115, y_train6116, y_train6117, y_train6118, y_train6121, y_train6122, y_train6123, y_train6124, y_train6125, y_train6126, y_train6127, y_train6128, y_train6131, y_train6132, y_train6133, y_train6134, y_train6135, y_train6136, y_train6137, y_train6138, y_train6141, y_train6142, y_train6143, y_train6144, y_train6145, y_train6146, y_train6147, y_train6148, y_train6151, y_train6152, y_train6153, y_train6154, y_train6155, y_train6156, y_train6157, y_train6158, y_train6162, y_train6163, y_train6164, y_train6165, y_train6166, y_train6167, y_train6168, y_train6171, y_train6172, y_train6173, y_train6174, y_train6175, y_train6176, y_train6177, y_train6178, y_train6181, y_train6182, y_train6183, y_train6184, y_train6185, y_train6186, y_train6187, y_train6188, y_train6211, y_train6212, y_train6213, y_train6214, y_train6215, y_train6216, y_train6217, y_train6218, y_train6221, y_train6222, y_train6223, y_train6224, y_train6225, y_train6226, y_train6227, y_train6228, y_train6231, y_train6232, y_train6233, y_train6234, y_train6235, y_train6236, y_train6237, y_train6238, y_train6241, y_train6242, y_train6243, y_train6244, y_train6245, y_train6246, y_train6247, y_train6248, y_train6251, y_train6252, y_train6253, y_train6254, y_train6255, y_train6256, y_train6257, y_train6258, y_train6261, y_train6263, y_train6264, y_train6265, y_train6266, y_train6267, y_train6268, y_train6271, y_train6272, y_train6273, y_train6274, y_train6275, y_train6276, y_train6277, y_train6278, y_train6281, y_train6282, y_train6283, y_train6284, y_train6285, y_train6286, y_train6287, y_train6288, y_train6311, y_train6312, y_train6313, y_train6314, y_train6315, y_train6316, y_train6317, y_train6318, y_train6321, y_train6322, y_train6323, y_train6324, y_train6325, y_train6326, y_train6327, y_train6328, y_train6331, y_train6332, y_train6333, y_train6334, y_train6335, y_train6336, y_train6337, y_train6338, y_train6341, y_train6342, y_train6343, y_train6344, y_train6345, y_train6346, y_train6347, y_train6348, y_train6351, y_train6352, y_train6353, y_train6354, y_train6355, y_train6356, y_train6357, y_train6358, y_train6361, y_train6362, y_train6364, y_train6365, y_train6366, y_train6367, y_train6368, y_train6371, y_train6372, y_train6373, y_train6374, y_train6375, y_train6376, y_train6377, y_train6378, y_train6381, y_train6382, y_train6383, y_train6384, y_train6385, y_train6386, y_train6387, y_train6388, y_train6411, y_train6412, y_train6413, y_train6414, y_train6415, y_train6416, y_train6417, y_train6418, y_train6421, y_train6422, y_train6423, y_train6424, y_train6425, y_train6426, y_train6427, y_train6428, y_train6431, y_train6432, y_train6433, y_train6434, y_train6435, y_train6436, y_train6437, y_train6438, y_train6441, y_train6442, y_train6443, y_train6444, y_train6445, y_train6446, y_train6447, y_train6448, y_train6451, y_train6452, y_train6453, y_train6454, y_train6455, y_train6456, y_train6457, y_train6458, y_train6461, y_train6462, y_train6463, y_train6465, y_train6466, y_train6467, y_train6468, y_train6471, y_train6472, y_train6473, y_train6474, y_train6475, y_train6476, y_train6477, y_train6478, y_train6481, y_train6482, y_train6483, y_train6484, y_train6485, y_train6486, y_train6487, y_train6488, y_train6511, y_train6512, y_train6513, y_train6514, y_train6515, y_train6516, y_train6517, y_train6518, y_train6521, y_train6522, y_train6523, y_train6524, y_train6525, y_train6526, y_train6527, y_train6528, y_train6531, y_train6532, y_train6533, y_train6534, y_train6535, y_train6536, y_train6537, y_train6538, y_train6541, y_train6542, y_train6543, y_train6544, y_train6545, y_train6546, y_train6547, y_train6548, y_train6551, y_train6552, y_train6553, y_train6554, y_train6555, y_train6556, y_train6557, y_train6558, y_train6561, y_train6562, y_train6563, y_train6564, y_train6566, y_train6567, y_train6568, y_train6571, y_train6572, y_train6573, y_train6574, y_train6575, y_train6576, y_train6577, y_train6578, y_train6581, y_train6582, y_train6583, y_train6584, y_train6585, y_train6586, y_train6587, y_train6588, y_train6611, y_train6612, y_train6613, y_train6614, y_train6615, y_train6616, y_train6617, y_train6618, y_train6621, y_train6622, y_train6623, y_train6624, y_train6625, y_train6626, y_train6627, y_train6628, y_train6631, y_train6632, y_train6633, y_train6634, y_train6635, y_train6636, y_train6637, y_train6638, y_train6641, y_train6642, y_train6643, y_train6644, y_train6645, y_train6646, y_train6647, y_train6648, y_train6651, y_train6652, y_train6653, y_train6654, y_train6655, y_train6656, y_train6657, y_train6658, y_train6661, y_train6662, y_train6663, y_train6664, y_train6665, y_train6667, y_train6668, y_train6671, y_train6672, y_train6673, y_train6674, y_train6675, y_train6676, y_train6677, y_train6678, y_train6681, y_train6682, y_train6683, y_train6684, y_train6685, y_train6686, y_train6687, y_train6688, y_train6711, y_train6712, y_train6713, y_train6714, y_train6715, y_train6716, y_train6717, y_train6718, y_train6721, y_train6722, y_train6723, y_train6724, y_train6725, y_train6726, y_train6727, y_train6728, y_train6731, y_train6732, y_train6733, y_train6734, y_train6735, y_train6736, y_train6737, y_train6738, y_train6741, y_train6742, y_train6743, y_train6744, y_train6745, y_train6746, y_train6747, y_train6748, y_train6751, y_train6752, y_train6753, y_train6754, y_train6755, y_train6756, y_train6757, y_train6758, y_train6761, y_train6762, y_train6763, y_train6764, y_train6765, y_train6766, y_train6768, y_train6771, y_train6772, y_train6773, y_train6774, y_train6775, y_train6776, y_train6777, y_train6778, y_train6781, y_train6782, y_train6783, y_train6784, y_train6785, y_train6786, y_train6787, y_train6788, y_train6811, y_train6812, y_train6813, y_train6814, y_train6815, y_train6816, y_train6817, y_train6818, y_train6821, y_train6822, y_train6823, y_train6824, y_train6825, y_train6826, y_train6827, y_train6828, y_train6831, y_train6832, y_train6833, y_train6834, y_train6835, y_train6836, y_train6837, y_train6838, y_train6841, y_train6842, y_train6843, y_train6844, y_train6845, y_train6846, y_train6847, y_train6848, y_train6851, y_train6852, y_train6853, y_train6854, y_train6855, y_train6856, y_train6857, y_train6858, y_train6861, y_train6862, y_train6863, y_train6864, y_train6865, y_train6866, y_train6867, y_train6871, y_train6872, y_train6873, y_train6874, y_train6875, y_train6876, y_train6877, y_train6878, y_train6881, y_train6882, y_train6883, y_train6884, y_train6885, y_train6886, y_train6887, y_train6888, y_train7111, y_train7112, y_train7113, y_train7114, y_train7115, y_train7116, y_train7117, y_train7118, y_train7121, y_train7122, y_train7123, y_train7124, y_train7125, y_train7126, y_train7127, y_train7128, y_train7131, y_train7132, y_train7133, y_train7134, y_train7135, y_train7136, y_train7137, y_train7138, y_train7141, y_train7142, y_train7143, y_train7144, y_train7145, y_train7146, y_train7147, y_train7148, y_train7151, y_train7152, y_train7153, y_train7154, y_train7155, y_train7156, y_train7157, y_train7158, y_train7161, y_train7162, y_train7163, y_train7164, y_train7165, y_train7166, y_train7167, y_train7168, y_train7172, y_train7173, y_train7174, y_train7175, y_train7176, y_train7177, y_train7178, y_train7181, y_train7182, y_train7183, y_train7184, y_train7185, y_train7186, y_train7187, y_train7188, y_train7211, y_train7212, y_train7213, y_train7214, y_train7215, y_train7216, y_train7217, y_train7218, y_train7221, y_train7222, y_train7223, y_train7224, y_train7225, y_train7226, y_train7227, y_train7228, y_train7231, y_train7232, y_train7233, y_train7234, y_train7235, y_train7236, y_train7237, y_train7238, y_train7241, y_train7242, y_train7243, y_train7244, y_train7245, y_train7246, y_train7247, y_train7248, y_train7251, y_train7252, y_train7253, y_train7254, y_train7255, y_train7256, y_train7257, y_train7258, y_train7261, y_train7262, y_train7263, y_train7264, y_train7265, y_train7266, y_train7267, y_train7268, y_train7271, y_train7273, y_train7274, y_train7275, y_train7276, y_train7277, y_train7278, y_train7281, y_train7282, y_train7283, y_train7284, y_train7285, y_train7286, y_train7287, y_train7288, y_train7311, y_train7312, y_train7313, y_train7314, y_train7315, y_train7316, y_train7317, y_train7318, y_train7321, y_train7322, y_train7323, y_train7324, y_train7325, y_train7326, y_train7327, y_train7328, y_train7331, y_train7332, y_train7333, y_train7334, y_train7335, y_train7336, y_train7337, y_train7338, y_train7341, y_train7342, y_train7343, y_train7344, y_train7345, y_train7346, y_train7347, y_train7348, y_train7351, y_train7352, y_train7353, y_train7354, y_train7355, y_train7356, y_train7357, y_train7358, y_train7361, y_train7362, y_train7363, y_train7364, y_train7365, y_train7366, y_train7367, y_train7368, y_train7371, y_train7372, y_train7374, y_train7375, y_train7376, y_train7377, y_train7378, y_train7381, y_train7382, y_train7383, y_train7384, y_train7385, y_train7386, y_train7387, y_train7388, y_train7411, y_train7412, y_train7413, y_train7414, y_train7415, y_train7416, y_train7417, y_train7418, y_train7421, y_train7422, y_train7423, y_train7424, y_train7425, y_train7426, y_train7427, y_train7428, y_train7431, y_train7432, y_train7433, y_train7434, y_train7435, y_train7436, y_train7437, y_train7438, y_train7441, y_train7442, y_train7443, y_train7444, y_train7445, y_train7446, y_train7447, y_train7448, y_train7451, y_train7452, y_train7453, y_train7454, y_train7455, y_train7456, y_train7457, y_train7458, y_train7461, y_train7462, y_train7463, y_train7464, y_train7465, y_train7466, y_train7467, y_train7468, y_train7471, y_train7472, y_train7473, y_train7475, y_train7476, y_train7477, y_train7478, y_train7481, y_train7482, y_train7483, y_train7484, y_train7485, y_train7486, y_train7487, y_train7488, y_train7511, y_train7512, y_train7513, y_train7514, y_train7515, y_train7516, y_train7517, y_train7518, y_train7521, y_train7522, y_train7523, y_train7524, y_train7525, y_train7526, y_train7527, y_train7528, y_train7531, y_train7532, y_train7533, y_train7534, y_train7535, y_train7536, y_train7537, y_train7538, y_train7541, y_train7542, y_train7543, y_train7544, y_train7545, y_train7546, y_train7547, y_train7548, y_train7551, y_train7552, y_train7553, y_train7554, y_train7555, y_train7556, y_train7557, y_train7558, y_train7561, y_train7562, y_train7563, y_train7564, y_train7565, y_train7566, y_train7567, y_train7568, y_train7571, y_train7572, y_train7573, y_train7574, y_train7576, y_train7577, y_train7578, y_train7581, y_train7582, y_train7583, y_train7584, y_train7585, y_train7586, y_train7587, y_train7588, y_train7611, y_train7612, y_train7613, y_train7614, y_train7615, y_train7616, y_train7617, y_train7618, y_train7621, y_train7622, y_train7623, y_train7624, y_train7625, y_train7626, y_train7627, y_train7628, y_train7631, y_train7632, y_train7633, y_train7634, y_train7635, y_train7636, y_train7637, y_train7638, y_train7641, y_train7642, y_train7643, y_train7644, y_train7645, y_train7646, y_train7647, y_train7648, y_train7651, y_train7652, y_train7653, y_train7654, y_train7655, y_train7656, y_train7657, y_train7658, y_train7661, y_train7662, y_train7663, y_train7664, y_train7665, y_train7666, y_train7667, y_train7668, y_train7671, y_train7672, y_train7673, y_train7674, y_train7675, y_train7677, y_train7678, y_train7681, y_train7682, y_train7683, y_train7684, y_train7685, y_train7686, y_train7687, y_train7688, y_train7711, y_train7712, y_train7713, y_train7714, y_train7715, y_train7716, y_train7717, y_train7718, y_train7721, y_train7722, y_train7723, y_train7724, y_train7725, y_train7726, y_train7727, y_train7728, y_train7731, y_train7732, y_train7733, y_train7734, y_train7735, y_train7736, y_train7737, y_train7738, y_train7741, y_train7742, y_train7743, y_train7744, y_train7745, y_train7746, y_train7747, y_train7748, y_train7751, y_train7752, y_train7753, y_train7754, y_train7755, y_train7756, y_train7757, y_train7758, y_train7761, y_train7762, y_train7763, y_train7764, y_train7765, y_train7766, y_train7767, y_train7768, y_train7771, y_train7772, y_train7773, y_train7774, y_train7775, y_train7776, y_train7778, y_train7781, y_train7782, y_train7783, y_train7784, y_train7785, y_train7786, y_train7787, y_train7788, y_train7811, y_train7812, y_train7813, y_train7814, y_train7815, y_train7816, y_train7817, y_train7818, y_train7821, y_train7822, y_train7823, y_train7824, y_train7825, y_train7826, y_train7827, y_train7828, y_train7831, y_train7832, y_train7833, y_train7834, y_train7835, y_train7836, y_train7837, y_train7838, y_train7841, y_train7842, y_train7843, y_train7844, y_train7845, y_train7846, y_train7847, y_train7848, y_train7851, y_train7852, y_train7853, y_train7854, y_train7855, y_train7856, y_train7857, y_train7858, y_train7861, y_train7862, y_train7863, y_train7864, y_train7865, y_train7866, y_train7867, y_train7868, y_train7871, y_train7872, y_train7873, y_train7874, y_train7875, y_train7876, y_train7877, y_train7881, y_train7882, y_train7883, y_train7884, y_train7885, y_train7886, y_train7887, y_train7888, y_train8111, y_train8112, y_train8113, y_train8114, y_train8115, y_train8116, y_train8117, y_train8118, y_train8121, y_train8122, y_train8123, y_train8124, y_train8125, y_train8126, y_train8127, y_train8128, y_train8131, y_train8132, y_train8133, y_train8134, y_train8135, y_train8136, y_train8137, y_train8138, y_train8141, y_train8142, y_train8143, y_train8144, y_train8145, y_train8146, y_train8147, y_train8148, y_train8151, y_train8152, y_train8153, y_train8154, y_train8155, y_train8156, y_train8157, y_train8158, y_train8161, y_train8162, y_train8163, y_train8164, y_train8165, y_train8166, y_train8167, y_train8168, y_train8171, y_train8172, y_train8173, y_train8174, y_train8175, y_train8176, y_train8177, y_train8178, y_train8182, y_train8183, y_train8184, y_train8185, y_train8186, y_train8187, y_train8188, y_train8211, y_train8212, y_train8213, y_train8214, y_train8215, y_train8216, y_train8217, y_train8218, y_train8221, y_train8222, y_train8223, y_train8224, y_train8225, y_train8226, y_train8227, y_train8228, y_train8231, y_train8232, y_train8233, y_train8234, y_train8235, y_train8236, y_train8237, y_train8238, y_train8241, y_train8242, y_train8243, y_train8244, y_train8245, y_train8246, y_train8247, y_train8248, y_train8251, y_train8252, y_train8253, y_train8254, y_train8255, y_train8256, y_train8257, y_train8258, y_train8261, y_train8262, y_train8263, y_train8264, y_train8265, y_train8266, y_train8267, y_train8268, y_train8271, y_train8272, y_train8273, y_train8274, y_train8275, y_train8276, y_train8277, y_train8278, y_train8281, y_train8283, y_train8284, y_train8285, y_train8286, y_train8287, y_train8288, y_train8311, y_train8312, y_train8313, y_train8314, y_train8315, y_train8316, y_train8317, y_train8318, y_train8321, y_train8322, y_train8323, y_train8324, y_train8325, y_train8326, y_train8327, y_train8328, y_train8331, y_train8332, y_train8333, y_train8334, y_train8335, y_train8336, y_train8337, y_train8338, y_train8341, y_train8342, y_train8343, y_train8344, y_train8345, y_train8346, y_train8347, y_train8348, y_train8351, y_train8352, y_train8353, y_train8354, y_train8355, y_train8356, y_train8357, y_train8358, y_train8361, y_train8362, y_train8363, y_train8364, y_train8365, y_train8366, y_train8367, y_train8368, y_train8371, y_train8372, y_train8373, y_train8374, y_train8375, y_train8376, y_train8377, y_train8378, y_train8381, y_train8382, y_train8384, y_train8385, y_train8386, y_train8387, y_train8388, y_train8411, y_train8412, y_train8413, y_train8414, y_train8415, y_train8416, y_train8417, y_train8418, y_train8421, y_train8422, y_train8423, y_train8424, y_train8425, y_train8426, y_train8427, y_train8428, y_train8431, y_train8432, y_train8433, y_train8434, y_train8435, y_train8436, y_train8437, y_train8438, y_train8441, y_train8442, y_train8443, y_train8444, y_train8445, y_train8446, y_train8447, y_train8448, y_train8451, y_train8452, y_train8453, y_train8454, y_train8455, y_train8456, y_train8457, y_train8458, y_train8461, y_train8462, y_train8463, y_train8464, y_train8465, y_train8466, y_train8467, y_train8468, y_train8471, y_train8472, y_train8473, y_train8474, y_train8475, y_train8476, y_train8477, y_train8478, y_train8481, y_train8482, y_train8483, y_train8485, y_train8486, y_train8487, y_train8488, y_train8511, y_train8512, y_train8513, y_train8514, y_train8515, y_train8516, y_train8517, y_train8518, y_train8521, y_train8522, y_train8523, y_train8524, y_train8525, y_train8526, y_train8527, y_train8528, y_train8531, y_train8532, y_train8533, y_train8534, y_train8535, y_train8536, y_train8537, y_train8538, y_train8541, y_train8542, y_train8543, y_train8544, y_train8545, y_train8546, y_train8547, y_train8548, y_train8551, y_train8552, y_train8553, y_train8554, y_train8555, y_train8556, y_train8557, y_train8558, y_train8561, y_train8562, y_train8563, y_train8564, y_train8565, y_train8566, y_train8567, y_train8568, y_train8571, y_train8572, y_train8573, y_train8574, y_train8575, y_train8576, y_train8577, y_train8578, y_train8581, y_train8582, y_train8583, y_train8584, y_train8586, y_train8587, y_train8588, y_train8611, y_train8612, y_train8613, y_train8614, y_train8615, y_train8616, y_train8617, y_train8618, y_train8621, y_train8622, y_train8623, y_train8624, y_train8625, y_train8626, y_train8627, y_train8628, y_train8631, y_train8632, y_train8633, y_train8634, y_train8635, y_train8636, y_train8637, y_train8638, y_train8641, y_train8642, y_train8643, y_train8644, y_train8645, y_train8646, y_train8647, y_train8648, y_train8651, y_train8652, y_train8653, y_train8654, y_train8655, y_train8656, y_train8657, y_train8658, y_train8661, y_train8662, y_train8663, y_train8664, y_train8665, y_train8666, y_train8667, y_train8668, y_train8671, y_train8672, y_train8673, y_train8674, y_train8675, y_train8676, y_train8677, y_train8678, y_train8681, y_train8682, y_train8683, y_train8684, y_train8685, y_train8687, y_train8688, y_train8711, y_train8712, y_train8713, y_train8714, y_train8715, y_train8716, y_train8717, y_train8718, y_train8721, y_train8722, y_train8723, y_train8724, y_train8725, y_train8726, y_train8727, y_train8728, y_train8731, y_train8732, y_train8733, y_train8734, y_train8735, y_train8736, y_train8737, y_train8738, y_train8741, y_train8742, y_train8743, y_train8744, y_train8745, y_train8746, y_train8747, y_train8748, y_train8751, y_train8752, y_train8753, y_train8754, y_train8755, y_train8756, y_train8757, y_train8758, y_train8761, y_train8762, y_train8763, y_train8764, y_train8765, y_train8766, y_train8767, y_train8768, y_train8771, y_train8772, y_train8773, y_train8774, y_train8775, y_train8776, y_train8777, y_train8778, y_train8781, y_train8782, y_train8783, y_train8784, y_train8785, y_train8786, y_train8788, y_train8811, y_train8812, y_train8813, y_train8814, y_train8815, y_train8816, y_train8817, y_train8818, y_train8821, y_train8822, y_train8823, y_train8824, y_train8825, y_train8826, y_train8827, y_train8828, y_train8831, y_train8832, y_train8833, y_train8834, y_train8835, y_train8836, y_train8837, y_train8838, y_train8841, y_train8842, y_train8843, y_train8844, y_train8845, y_train8846, y_train8847, y_train8848, y_train8851, y_train8852, y_train8853, y_train8854, y_train8855, y_train8856, y_train8857, y_train8858, y_train8861, y_train8862, y_train8863, y_train8864, y_train8865, y_train8866, y_train8867, y_train8868, y_train8871, y_train8872, y_train8873, y_train8874, y_train8875, y_train8876, y_train8877, y_train8878, y_train8881, y_train8882, y_train8883, y_train8884, y_train8885, y_train8886, y_train8887])

# %%
len(y_vals)

# %%
# batch_size = 9351
batch_size = 300

x_data = tf.placeholder(shape=[None, 64], dtype = tf.float32)
y_target = tf.placeholder(shape=[4032,None], dtype = tf.float32)
prediction_grid = tf.placeholder(shape = [None, 64], dtype=tf.float32)

b = tf.Variable(tf.random_normal(shape=[4032,batch_size]))

# %%
gamma = tf.constant(-10.0)
dist = tf.reduce_sum(tf.square(x_data),1)
dist = tf.reshape(dist, [-1,1])
sq_distance = tf.add(tf.subtract(dist, tf.multiply(2.0, tf.matmul(x_data, tf.transpose(x_data)))), tf.transpose(dist))
my_kernel = tf.exp(tf.multiply(gamma, tf.abs(sq_distance)))

# %%
def reshape_matmul(mat):
    v1 = tf.expand_dims(mat, 1)
    v2 = tf.reshape(v1, [4032, batch_size, 1])
    return tf.matmul(v2, v1)

# %%
first_term = tf.reduce_sum(b)
b_vec_cross = tf.matmul(tf.transpose(b),b)
y_target_cross = reshape_matmul(y_target)

second_term = tf.reduce_sum(tf.multiply(my_kernel, tf.multiply(b_vec_cross, y_target_cross)), [1,2])
loss = tf.reduce_sum(tf.negative(tf.subtract(first_term, second_term)))

# %%
rA = tf.reshape(tf.reduce_sum(tf.square(x_data), 1), [-1,1])
rB = tf.reshape(tf.reduce_sum(tf.square(prediction_grid), 1), [-1,1])

pred_sq_dist = tf.add(tf.subtract(rA, tf.multiply(2.0, tf.matmul(x_data, tf.transpose(prediction_grid)))), tf.transpose(rB))
pred_kernel = tf.exp(tf.multiply(gamma, tf.abs(pred_sq_dist)))

# %%
prediction_output = tf.matmul(tf.multiply(y_target, b), pred_kernel)
prediction = tf.argmax(prediction_output - tf.expand_dims(tf.reduce_mean(prediction_output, 1), 1), 0)

# %%
accuracy = tf.reduce_mean(tf.cast(tf.equal(prediction, tf.argmax(y_target,0)), tf.float32))

# %%
my_optim = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train_step = my_optim.minimize(loss)
init = tf.global_variables_initializer()
session.run(init)

# %%
loss_vec = []
batch_acc = []

for i in range(200):
    rand_idx = np.random.choice(len(matriz), size= batch_size)
    rand_x = matriz[rand_idx]
    rand_y = y_vals[:,rand_idx]
    session.run(train_step, feed_dict={x_data: rand_x, y_target: rand_y})
    
    temp_loss = session.run(loss, feed_dict={x_data:rand_x, y_target: rand_y})
    loss_vec.append(temp_loss)
    
    acc_temp = session.run(accuracy, feed_dict={x_data: rand_x, y_target: rand_y, prediction_grid:rand_x})
    batch_acc.append(acc_temp)
    
    if (i+1)% 25 == 0:
        print("Paso #"+str(i+1)+ ", Loss = "+str(temp_loss)+ ", Precision = "+str(acc_temp))

# %%
plt.plot(loss_vec, 'k-')
plt.title("Perdidas por iteracion")
plt.show()

# %%
plt.plot(batch_acc, 'k-', label="Precision")
plt.title("Precision en la clasificacion")
plt.xlabel("numero de iteraccion")
plt.ylabel("Precision")
plt.legend(loc="lower right")
plt.ylim(0,1)
plt.show()

# %%
count = 0
for i in range(1112,8888):
    s = math.floor(i/100)
    se = math.floor(i % 100)
    if(s != se):
        if(s % 10 != 0):
            if(s % 10 != 9):
                if(i % 10 != 0):
                    sec = i/10
                    if(math.floor(sec % 10) != 0):
                        if(i % 10 != 9):
                            sec_2 = i/10
                            if(math.floor(sec % 10) != 9):
                                count = count + 1
                                print(i)
                            
print(count)
# Out:
# 1112
# 1113
# 1114
# 1115
# 1116
# 1117
# 1118
# 1121
# 1122
# 1123
# 1124
# 1125
# 1126
# 1127
# 1128
# 1131
# 1132
# 1133
# 1134
# 1135
# 1136
# 1137
# 1138
# 1141
# 1142
# 1143
# 1144
# 1145
# 1146
# 1147
# 1148
# 1151
# 1152
# 1153
# 1154
# 1155
# 1156
# 1157
# 1158
# 1161
# 1162
# 1163
# 1164
# 1165
# 1166
# 1167
# 1168
# 1171
# 1172
# 1173
# 1174
# 1175
# 1176
# 1177
# 1178
# 1181
# 1182
# 1183
# 1184
# 1185
# 1186
# 1187
# 1188
# 1211
# 1213
# 1214
# 1215
# 1216
# 1217
# 1218
# 1221
# 1222
# 1223
# 1224
# 1225
# 1226
# 1227
# 1228
# 1231
# 1232
# 1233
# 1234
# 1235
# 1236
# 1237
# 1238
# 1241
# 1242
# 1243
# 1244
# 1245
# 1246
# 1247
# 1248
# 1251
# 1252
# 1253
# 1254
# 1255
# 1256
# 1257
# 1258
# 1261
# 1262
# 1263
# 1264
# 1265
# 1266
# 1267
# 1268
# 1271
# 1272
# 1273
# 1274
# 1275
# 1276
# 1277
# 1278
# 1281
# 1282
# 1283
# 1284
# 1285
# 1286
# 1287
# 1288
# 1311
# 1312
# 1314
# 1315
# 1316
# 1317
# 1318
# 1321
# 1322
# 1323
# 1324
# 1325
# 1326
# 1327
# 1328
# 1331
# ...

# %%
# cadena = ''
# for i in range(1112,8888):
#     s = math.floor(i/100)
#     se = math.floor(i % 100)
#     if(s != se):
#         if(s % 10 != 0):
#             if(s % 10 != 9):
#                 if(i % 10 != 0):
#                     sec = i/10
#                     if(math.floor(sec % 10) != 0):
#                         if(i % 10 != 9):
#                             sec_2 = i/10
#                             if(math.floor(sec % 10) != 9):
#                                 cadena = cadena +',' +' y_train'+str(i)
                            
# print(cadena)
